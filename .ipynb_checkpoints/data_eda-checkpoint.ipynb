# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Senior Scientist, AAV Plasmid and Vector Platf...
# 1               Sr.Data Scientist/Computer Scientist
# 2                                      Data Engineer
# 3                                   Sr Data Engineer
# 4                                   Senior Scientist
#
#                 Salary Estimate  \
# 0  $101K-$129K (Glassdoor Est.)
# 1  $101K-$129K (Glassdoor Est.)
# 2  $101K-$129K (Glassdoor Est.)
# 3  $101K-$129K (Glassdoor Est.)
# 4  $101K-$129K (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Homology Medicines is seeking an outstanding S...     4.4
# 1  Why choose between doing meaningful work and h...     3.3
# 2  Our client is a leading hedge fund looking to ...     4.2
# 3  Group O is seeking a strong candidate in the j...     3.1
# 4  Position Description:\r\nThe position’s primar...     2.9
#
#                       Company Name         Location            Headquarters  \
# 0  Homology Medicines, Inc.\r\n4.4      Bedford, MA             Bedford, MA
# 1                     MITRE\r\n3.3       McLean, VA             Bedford, MA
# 2       NJF Global Holdings\r\n4.2     New York, NY  London, United Kingdom
# 3                   Group O\r\n3.1  San Antonio, TX               Milan, IL
# 4                  Exelixis\r\n2.9      Alameda, CA             Alameda, CA
#
#                       Size  Founded        Type of ownership  ... avg_salary  \
# 0      51 to 200 employees       -1         Company - Public  ...      115.0
# 1  5001 to 10000 employees     1958  Non-profit Organisation  ...      115.0
# 2      51 to 200 employees     2003        Company - Private  ...      115.0
# 3   1001 to 5000 employees     1974        Company - Private  ...      115.0
# 4    501 to 1000 employees     1994         Company - Public  ...      115.0
#
#                     company_txt job_state same_state  comp_age  python_yn  \
# 0  Homology Medicines, Inc.\r\n        MA          1        -1          0
# 1                     MITRE\r\n        VA          0        62          1
# 2       NJF Global Holdings\r\n        NY          0        17          1
# 3                   Group O\r\n        TX          0        46          1
# 4                  Exelixis\r\n        CA          1        26          0
#
#    r_yn  spark_yn aws_yn excel_yn
# 0     0         0      0        1
# 1     0         1      0        0
# 2     0         0      0        0
# 3     0         0      0        1
# 4     0         0      0        0
#
# [5 rows x 27 columns]

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'min_salary', 'max_salary', 'avg_salary', 'company_txt',
#        'job_state', 'same_state', 'comp_age', 'python_yn', 'r_yn', 'spark_yn',
#        'aws_yn', 'excel_yn'],
#       dtype='object')

# %%
#Job title and seniority 
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr.' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
            return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower() or 'junior' in title.lower():
        return 'junior'
    else:
        return 'na'

# %%
df['job_simple'] = df['Job Title'].apply(title_simplifier)

# %%
df.job_simple.value_counts()
# Out:
# na                703
# data engineer     588
# data scientist    353
# analyst           126
# mle               111
# director           99
# manager            20
# Name: job_simple, dtype: int64

# %%
df['seniority'] = df['Job Title'].apply(seniority)

# %%
df.seniority.value_counts()
# Out:
# senior    1110
# na         888
# junior       2
# Name: seniority, dtype: int64

# %%
df.job_state.value_counts()
# Out:
# CA        604
# MA        368
# NY        185
# VA        137
# WI        110
# UT        103
# IN         62
# AZ         61
# SC         59
# TN         56
# TX         28
# IL         24
# MD         22
# NC         18
# PA         18
# FL         17
# OH         13
# MO         13
# CO         12
# WA         12
# NJ         10
# Remote      9
# NH          8
# DC          8
# US          6
# AL          6
# MN          6
# MI          5
# NE          4
# GA          3
# DE          2
# IA          2
# CT          2
# HI          2
# LA          1
# MS          1
# KY          1
# KS          1
# OR          1
# Name: job_state, dtype: int64

# %%
#Job description length 
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))
df.desc_len
# Out:
# 0       2323
# 1       3725
# 2       1366
# 3       2657
# 4       3714
#         ...
# 1995    2527
# 1996       2
# 1997    2157
# 1998    2378
# 1999    3217
# Name: desc_len, Length: 2000, dtype: int64

# %%
#Competitor count
df['num_comp'] = df.Competitors.apply(lambda x: len(x.split(',')) if x != -1 else 0)

# %%
df.num_comp
# Out:
# 0       1
# 1       3
# 2       1
# 3       1
# 4       3
#        ..
# 1995    3
# 1996    1
# 1997    1
# 1998    1
# 1999    1
# Name: num_comp, Length: 2000, dtype: int64

# %%
#Hourly wage to annual
df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis = 1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis = 1)

# %%
df[df.hourly == 1][['hourly', 'min_salary', 'max_salary']]
# Out:
#       hourly  min_salary  max_salary
# 1956       1          42          76
# 1957       1          42          76
# 1958       1          42          76
# 1959       1          42          76
# 1960       1          42          76
# 1961       1          42          76
# 1962       1          42          76
# 1963       1          42          76
# 1964       1          42          76
# 1965       1          42          76
# 1966       1          42          76
# 1967       1          42          76
# 1968       1          42          76
# 1969       1          42          76
# 1970       1          42          76
# 1971       1          42          76
# 1972       1          42          76
# 1973       1          42          76
# 1974       1          42          76
# 1975       1          42          76
# 1976       1          42          76
# 1977       1          42          76
# 1978       1          42          76
# 1979       1          42          76
# 1980       1          42          76
# 1981       1          42          76
# 1982       1          42          76
# 1983       1          42          76
# 1984       1          42          76
# 1985       1          42          76

# %%
df.company_txt = df.company_txt.apply(lambda x: x.replace('\n', '').replace('\r', ''))
df.company_txt
# Out:
# 0                Homology Medicines, Inc.
# 1                                   MITRE
# 2                     NJF Global Holdings
# 3                                 Group O
# 4                                Exelixis
#                       ...
# 1995    DICK'S Sporting Goods - Corporate
# 1996    DICK'S Sporting Goods - Corporate
# 1997                     Point72 Ventures
# 1998                             SpringML
# 1999      Scientific Research Corporation
# Name: company_txt, Length: 2000, dtype: object

# %%
df.describe()
# Out:
#             Rating      Founded       hourly  min_salary   max_salary  \
# count  2000.000000  2000.000000  2000.000000  2000.00000  2000.000000
# mean      3.749800  1775.847000     0.015000    93.02950   170.893500
# std       0.704108   614.252004     0.121583    17.59086    33.654918
# min      -1.000000    -1.000000     0.000000    42.00000    76.000000
# 25%       3.500000  1964.000000     0.000000    99.00000   149.000000
# 50%       3.900000  1994.000000     0.000000    99.00000   188.000000
# 75%       4.000000  2008.000000     0.000000    99.00000   188.000000
# max       5.000000  2019.000000     1.000000   169.00000   281.000000
#
#         avg_salary   same_state     comp_age    python_yn         r_yn  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000
# mean    131.519000     0.495500    28.810000     0.465500     0.001000
# std      26.659337     0.500105    30.085469     0.498933     0.031615
# min      29.500000     0.000000    -1.000000     0.000000     0.000000
# 25%     122.000000     0.000000     9.000000     0.000000     0.000000
# 50%     143.500000     0.000000    24.000000     0.000000     0.000000
# 75%     143.500000     1.000000    39.000000     1.000000     0.000000
# max     225.000000     1.000000   239.000000     1.000000     1.000000
#
#           spark_yn       aws_yn     excel_yn      desc_len     num_comp
# count  2000.000000  2000.000000  2000.000000   2000.000000  2000.000000
# mean      0.226500     0.339000     0.433500   3881.447000     1.444500
# std       0.418671     0.473488     0.495682   1791.204482     0.795762
# min       0.000000     0.000000     0.000000      2.000000     1.000000
# 25%       0.000000     0.000000     0.000000   2872.000000     1.000000
# 50%       0.000000     0.000000     0.000000   3605.000000     1.000000
# 75%       0.000000     1.000000     1.000000   4951.000000     2.000000
# max       1.000000     1.000000     1.000000  10681.000000     3.000000

# %%
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.comp_age.hist()

# %%
df.desc_len.hist()

# %%
df.boxplot(column = ['comp_age','avg_salary','Rating'])

# %%
df.boxplot(column = 'Rating')

# %%
df[['comp_age','avg_salary','Rating','desc_len']].corr()
# Out:
#             comp_age  avg_salary    Rating  desc_len
# comp_age    1.000000   -0.066312 -0.036242  0.177023
# avg_salary -0.066312    1.000000  0.026845  0.093688
# Rating     -0.036242    0.026845  1.000000  0.064171
# desc_len    0.177023    0.093688  0.064171  1.000000

# %%
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(df[['comp_age','avg_salary','Rating','desc_len', 'num_comp']].corr(),vmin=-0.25,vmax=0.25, center=0, cmap=cmap,
            square=True, linewidths=.5, annot = True, fmt='.1g')

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'min_salary', 'max_salary', 'avg_salary', 'company_txt',
#        'job_state', 'same_state', 'comp_age', 'python_yn', 'r_yn', 'spark_yn',
#        'aws_yn', 'excel_yn', 'job_simple', 'seniority', 'desc_len',
#        'num_comp'],
#       dtype='object')

# %%
df_cat = df[['Location', 'Headquarters', 'Size','Type of ownership', 'Industry', 'Sector', 'Revenue', 'company_txt', 'job_state','same_state', 'python_yn', 'r_yn', 'spark_yn',
       'aws_yn', 'excel_yn', 'job_simple', 'seniority']]

# %%
for i in df_cat.columns:
    cat_num = df_cat[i].value_counts()
    print(f"Graph for {i}: total = {len(cat_num)}")
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: total = 215
# Graph for Headquarters: total = 221
# Graph for Size: total = 9
# Graph for Type of ownership: total = 12
# Graph for Industry: total = 65
# Graph for Sector: total = 24
# Graph for Revenue: total = 12
# Graph for company_txt: total = 396
# Graph for job_state: total = 39
# Graph for same_state: total = 2
# Graph for python_yn: total = 2
# Graph for r_yn: total = 2
# Graph for spark_yn: total = 2
# Graph for aws_yn: total = 2
# Graph for excel_yn: total = 2
# Graph for job_simple: total = 7
# Graph for seniority: total = 3

# %%
for i in df_cat[['Location','Headquarters','company_txt']].columns:
    cat_num = df_cat[i].value_counts()[:20]
    print(f"Graph for {i}: total = {len(cat_num)}")
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: total = 20
# Graph for Headquarters: total = 20
# Graph for company_txt: total = 20

# %%
pd.pivot_table(df, index = 'job_simple', values = 'avg_salary')
# Out:
#                 avg_salary
# job_simple
# analyst         115.210317
# data engineer   137.882653
# data scientist  115.667139
# director        140.212121
# manager         102.025000
# mle             137.328829
# na              135.776671

# %%
pd.pivot_table(df, index = ['job_simple','seniority'], values = 'avg_salary')
# Out:
#                           avg_salary
# job_simple     seniority
# analyst        junior     112.500000
#                na          98.767241
#                senior     129.742424
# data engineer  na         127.846386
#                senior     141.830569
# data scientist na         111.270992
#                senior     128.324176
# director       na         138.372549
#                senior     142.166667
# manager        na          96.500000
#                senior     112.285714
# mle            na         104.200000
#                senior     140.608911
# na             na         132.318598
#                senior     138.801333

# %%
pd.pivot_table(df, index = ['job_state','job_simple'], values = 'avg_salary').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_simple
# WI        na              139.959184
#           mle              82.500000
#           data scientist  103.166667
#           analyst          89.285714
# WA        data scientist   95.357143
# ...                              ...
# AZ        director        111.500000
#           na               82.500000
# AL        na              101.000000
#           data scientist   86.250000
#           data engineer   122.500000
#
# [131 rows x 1 columns]

# %%
pd.options.display.max_rows
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df, index = ['job_state','job_simple'], values = 'avg_salary', aggfunc = 'count').sort_values('job_state', ascending = False)
# Out:
#                           avg_salary
# job_state job_simple
# WI        na                      98
#           mle                      2
#           data scientist           3
#           analyst                  7
# WA        data scientist           7
#           data engineer            2
#           analyst                  3
# VA        na                      94
#           mle                      4
#           data scientist          27
#           data engineer           10
#           analyst                  2
# UT        data engineer           94
#           analyst                  1
#           data scientist           6
#           manager                  1
#           na                       1
# US        data scientist           2
#           data engineer            4
# TX        na                       4
#           data scientist          11
#           data engineer           11
#           analyst                  2
# TN        data scientist           3
#           data engineer           51
#           analyst                  2
# SC        na                      51
#           manager                  2
#           analyst                  6
# Remote    data engineer            2
#           analyst                  1
#           data scientist           1
#           na                       1
#           mle                      4
# PA        na                       2
#           mle                      3
#           data scientist           6
#           analyst                  7
# OR        data scientist           1
# OH        na                       6
#           data scientist           5
#           data engineer            2
# NY        analyst                 46
#           director                46
#           data scientist          33
#           data engineer           52
#           manager                  2
#           na                       6
# NJ        na                       3
#           director                 1
#           data scientist           2
#           analyst                  4
# NH        analyst                  4
#           data scientist           1
#           na                       3
# NE        na                       1
#           data scientist           3
# NC        na                       8
#           mle                      1
#           manager                  4
#           data scientist           4
#           data engineer            1
# MS        na                       1
# MO        data scientist           8
#           na                       1
#           data engineer            3
#           analyst                  1
# MN        na                       3
#           data scientist           2
#           analyst                  1
# MI        data engineer            2
#           analyst                  3
# MD        na                       5
#           data scientist          11
#           data engineer            1
#           analyst                  5
# MA        data scientist          70
#           director                 1
#           analyst                  5
#           data engineer           51
#           manager                  3
#           mle                      3
#           na                     235
# LA        analyst                  1
# KY        data scientist           1
# KS        data scientist           1
# IN        na                      55
#           data scientist           2
#           data engineer            4
#           analyst                  1
# IL        director                 1
#           data engineer            6
#           data scientist           9
#           analyst                  3
#           manager                  2
#           na                       3
# IA        analyst                  2
# HI        data scientist           2
# GA        data engineer            2
#           data scientist           1
# FL        na                       2
#           manager                  3
#           director                 2
#           data scientist           7
#           data engineer            1
#           analyst                  2
# DE        na                       1
#           data engineer            1
# DC        data scientist           6
#           analyst                  2
# CT        data scientist           2
# CO        data scientist           1
#           analyst                  4
#           data engineer            2
#           mle                      1
#           na                       4
# CA        na                     111
#           mle                     93
#           manager                  3
#           director                46
#           data scientist         111
#           data engineer          236
#           analyst                  4
# AZ        data scientist           2
#           data engineer           47
#           analyst                  7
#           director                 2
#           na                       3
# AL        na                       1
#           data scientist           2
#           data engineer            3

# %%
pd.pivot_table(df[df.job_simple == 'data scientist'], index = 'job_state', values = 'avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
# KS         148.500000
# PA         146.666667
# IN         134.750000
# MN         134.500000
# MA         133.335714
# CT         128.500000
# KY         122.000000
# GA         122.000000
# US         120.750000
# CA         120.045045
# CO         119.500000
# OR         119.500000
# NJ         118.750000
# DC         115.250000
# TN         114.000000
# UT         111.333333
# NE         111.166667
# VA         110.944444
# TX         110.500000
# NY         107.530303
# WI         103.166667
# FL         102.000000
# Remote      97.000000
# WA          95.357143
# IL          95.333333
# AZ          94.750000
# NC          90.250000
# OH          89.000000
# HI          87.500000
# AL          86.250000
# MO          84.375000
# MD          81.636364
# NH          29.500000

# %%
df_pivots = df[['Rating', 'Industry', 'Sector', 'Revenue', 'num_comp', 'hourly', 'python_yn', 'r_yn', 'spark_yn', 'aws_yn', 'excel_yn', 'Type of ownership','avg_salary']]

# %%
for i in df_pivots.columns:
    if i != 'avg_salary':
        print(f'{i}\n******************************************************')
        print(pd.pivot_table(df_pivots,index =i, values = 'avg_salary').sort_values('avg_salary', ascending = False))
        print()
# Out:
# Rating
# ******************************************************
#         avg_salary
# Rating
#  2.3    144.500000
#  3.9    140.126894
#  4.0    136.075321
#  4.2    136.073099
#  3.2    135.831818
#  4.5    135.316176
#  4.9    133.833333
#  3.3    133.580645
#  2.9    133.423729
#  3.6    132.351852
#  4.1    131.284091
#  3.1    128.919118
#  5.0    128.857143
#  3.4    128.676829
#  3.7    126.806250
#  3.5    125.186747
#  3.8    122.989796
#  4.3    121.863636
# -1.0    120.195652
#  1.9    119.500000
#  2.6    115.833333
#  2.8    111.833333
#  2.2    109.250000
#  4.6    105.142857
#  2.0    103.500000
#  2.5    102.833333
#  2.4    101.000000
#  4.7    100.846154
#  4.4     96.045455
#  3.0     94.045455
#  2.7     89.000000
#  4.8     83.593750
#
# Industry
# ******************************************************
#                                          avg_salary
# Industry
# Sporting Goods Shops                     225.000000
# Utilities                                148.500000
# Religious Organisations                  143.500000
# Health Charities                         143.500000
# Membership Organisations                 142.989362
# Computer Hardware & Software             139.912791
# Government Agencies                      139.452381
# Motor Vehicle Parts & Accessories Shops  137.798077
# Advertising & Marketing                  136.346154
# Healthcare Services & Hospitals          135.414706
# Insurance Operators                      135.152174
# Healthcare Product Manufacturing         134.750000
# Biotech & Pharmaceuticals                133.298898
# Aerospace & Defence                      132.522059
# Enterprise Software & Network Solutions  132.030864
# Internet                                 131.910448
# -1                                       127.323308
# Staffing & Outsourcing                   126.013333
# Pet & Pet Supply Shops                   122.000000
# Food Production                          122.000000
# Grocery Shops & Supermarkets             122.000000
# Sports & Recreation                      121.000000
# Other Retail Shops                       120.500000
# Insurance Agencies & Brokerages          120.250000
# Logistics & Supply Chain                 119.500000
# Charitable Foundations                   119.500000
# Legal                                    119.500000
# Food & Beverage Shops                    118.833333
# Investment Banking & Asset Management    118.444444
# Real Estate                              117.250000
# IT Services                              116.065421
# Chemical Manufacturing                   116.000000
# Consumer Electronics & Appliance Shops   112.500000
# Consumer Product Hire                    111.500000
# Video Games                              111.250000
# Research & Development                   110.900000
# Lending                                  110.730769
# Travel Agencies                          110.250000
# Consulting                               109.375000
# Food & Drink Manufacturing               108.250000
# Colleges & Universities                  107.400000
# Energy                                   107.000000
# Financial Transaction Processing         105.666667
# Electrical & Electronic Manufacturing    104.166667
# Cable, Internet & Telephone Providers    101.000000
# Telecommunications Services              101.000000
# Wholesale                                 98.833333
# Building & Construction                   98.000000
# Transportation Equipment Manufacturing    97.000000
# Architectural & Engineering Services      95.833333
# Consumer Products Manufacturing           93.277778
# Miscellaneous Manufacturing               91.666667
# Banks & Building Societies                83.111111
# Telecommunications Manufacturing          82.750000
# Home Furniture and Houseware Shops        82.666667
# Health, Beauty & Fitness                  82.500000
# Venture Capital & Private Equity          79.300000
# Accounting                                77.000000
# Brokerage Services                        72.625000
# Financial Analytics & Research            68.500000
# Department, Clothing, & Shoe Shops        68.500000
# News Outlets                              68.500000
# Transportation Management                 57.333333
# Industrial Manufacturing                  29.500000
# Farm Support Services                     29.500000
#
# Sector
# ******************************************************
#                                   avg_salary
# Sector
# Non-Profits                       143.236264
# Government                        139.452381
# Healthcare                        135.414706
# Insurance                         134.897436
# Biotech & Pharmaceuticals         133.298898
# Retail                            133.053030
# Information Technology            132.649123
# Aerospace & Defence               132.522059
# Business Services                 130.336466
# -1                                127.323308
# Arts, Entertainment & Recreation  121.000000
# Oil, Gas, Energy & Utilities      120.833333
# Real Estate                       117.250000
# Travel & Tourism                  110.250000
# Education                         107.400000
# Media                             102.700000
# Consumer Services                 101.833333
# Manufacturing                     100.166667
# Finance                            98.318182
# Building, Repair & Maintenance     98.000000
# Telecommunications                 91.875000
# Accounting & Legal                 91.166667
# Transportation & Logistics         82.200000
# Agriculture & Forestry             75.750000
#
# Revenue
# ******************************************************
#                                   avg_salary
# Revenue
# ₹50 to ₹100 million (INR)         139.000000
# ₹10 to ₹50 billion (INR)          135.382353
# ₹500 million to ₹1 billion (INR)  133.460317
# Unknown / Non-Applicable          133.408163
# ₹100 to ₹500 billion (INR)        131.260309
# ₹1 to ₹5 billion (INR)            130.823077
# ₹500+ billion (INR)               130.525641
# ₹5 to ₹10 billion (INR)           128.865385
# ₹100 to ₹500 million (INR)        126.211679
# -1                                119.860656
# ₹10 to ₹50 million (INR)          115.812500
# ₹50 to ₹100 billion (INR)         110.976190
#
# num_comp
# ******************************************************
#           avg_salary
# num_comp
# 2         133.696581
# 3         131.575130
# 1         131.334335
#
# hourly
# ******************************************************
#         avg_salary
# hourly
# 0       133.072589
# 1        29.500000
#
# python_yn
# ******************************************************
#            avg_salary
# python_yn
# 0          132.751169
# 1          130.104189
#
# r_yn
# ******************************************************
#       avg_salary
# r_yn
# 0     131.522022
# 1     128.500000
#
# spark_yn
# ******************************************************
#           avg_salary
# spark_yn
# 1         132.928256
# 0         131.106335
#
# aws_yn
# ******************************************************
#         avg_salary
# aws_yn
# 1       134.906342
# 0       129.781770
#
# excel_yn
# ******************************************************
#           avg_salary
# excel_yn
# 0         131.649603
# 1         131.348328
#
# Type of ownership
# ******************************************************
#                                 avg_salary
# Type of ownership
# Government                      140.580000
# Non-profit Organisation         137.396789
# Company - Public                136.667479
# Company - Private               126.945000
# -1                              119.860656
# Other Organisation              113.500000
# Unknown                         108.062500
# College / University            107.400000
# Subsidiary or Business Segment   98.980769
# Hospital                         89.500000
# Contract                         86.250000
# Private Practice / Firm          81.500000

# %%
from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc, interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda_data.csv', index = False)
